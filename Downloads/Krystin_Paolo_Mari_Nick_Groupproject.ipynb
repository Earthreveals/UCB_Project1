# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from pathlib import Path

# %%
#Read path with Pandas
Polarbear_data = pd.read_csv('CS_SB_PBearMeasurementData_1981_2017.csv')
Polarbear_data
# Out:
#      Collecting_Agency Population        Date  BearID Sex Age Total_Length  \
# 0                 USGS         SB  1982-04-09       1   M  17          218
# 1                 USGS         SB  1986-05-04       1   M  21          240
# 2                 USGS         SB  1987-04-21       1   M  22          238
# 3                 USGS         SB  1987-04-06       2   F  18          212
# 4                 USGS         SB  1981-10-19       2   F  12          198
# ...                ...        ...         ...     ...  ..  ..          ...
# 3166              USGS         SB  2009-05-08    2290   F  10          226
# 3167              USGS         SB  2006-04-03    2291   F  13          227
# 3168              USGS         SB  2006-04-03    2292   F   1          167
# 3169              USGS         SB  2016-04-22    2293   F  10      no data
# 3170              USGS         SB  2010-04-25    2294   F   9          222
#
#      Standard_Length Heart_Girth Skull_Width  ... Condition_Score  \
# 0            no data         140     no data  ...               2
# 1              219.4         149          24  ...               2
# 2              216.4         129          24  ...               3
# 3              196.5         127          22  ...               4
# 4            no data         175     no data  ...               4
# ...              ...         ...         ...  ...             ...
# 3166           199.2       124.7        20.3  ...               3
# 3167             200       125.3        21.5  ...               3
# 3168             148        81.5        14.6  ...               3
# 3169             201         124        20.5  ...               3
# 3170             202         115        20.5  ...               3
#
#      Number_of_cubs Cub_Age Gut_Fill Litter_mass Fat_In_Adipose Gut_Fill_Obs  \
# 0               NaN     NaN  no data         NaN        no data      no data
# 1               NaN     NaN  no data         NaN        no data      no data
# 2               NaN     NaN  no data         NaN        no data      no data
# 3                 0     NaN  no data       196.5        no data      no data
# 4                 2      C2  no data     no data        no data      no data
# ...             ...     ...      ...         ...            ...          ...
# 3166              0     NaN  no data       199.2        no data      no data
# 3167              1      C1  no data         200        no data      no data
# 3168            NaN     NaN  no data         NaN        no data      no data
# 3169              0     NaN  no data         201        no data      no data
# 3170              0     NaN        0         202        no data      no data
#
#      Snout_Vent_Length Resistance Percent_Body_Fat
# 0              no data    no data          no data
# 1              no data    no data          no data
# 2              no data    no data          no data
# 3              no data    no data          no data
# 4              no data    no data          no data
# ...                ...        ...              ...
# 3166           no data    no data          no data
# 3167           no data    no data          no data
# 3168           no data    no data          no data
# 3169           no data    no data          no data
# 3170           no data    no data          no data
#
# [3171 rows x 22 columns]

# %%
# Get info on the Dataset
Polarbear_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3171 entries, 0 to 3170
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Collecting_Agency  3171 non-null   object
#  1   Population         3171 non-null   object
#  2   Date               3171 non-null   object
#  3   BearID             3171 non-null   int64
#  4   Sex                3171 non-null   object
#  5   Age                3171 non-null   object
#  6   Total_Length       2703 non-null   object
#  7   Standard_Length    3171 non-null   object
#  8   Heart_Girth        3171 non-null   object
#  9   Skull_Width        3171 non-null   object
#  10  Tail_Length        3171 non-null   object
#  11  Mass               3171 non-null   object
#  12  Condition_Score    3171 non-null   object
#  13  Number_of_cubs     994 non-null    object
#  14  Cub_Age            610 non-null    object
#  15  Gut_Fill           2836 non-null   object
#  16  Litter_mass        880 non-null    object
#  17  Fat_In_Adipose     3171 non-null   object
#  18  Gut_Fill_Obs       3171 non-null   object
#  19  Snout_Vent_Length  3171 non-null   object
#  20  Resistance         3171 non-null   object
#  21  Percent_Body_Fat   3169 non-null   object
# dtypes: int64(1), object(21)
# memory usage: 545.1+ KB

# %%
cleaned_polarbear = Polarbear_data[['Date', 'Sex', 'Age', 'Mass', 'Total_Length', 'Number_of_cubs’]]
cleaned_polarbear
# Out:
#             Date Sex Age     Mass Total_Length Number_of_cubs
# 0     1982-04-09   M  17    267.6          218            NaN
# 1     1986-05-04   M  21  no data          240            NaN
# 2     1987-04-21   M  22  no data          238            NaN
# 3     1987-04-06   F  18  no data          212              0
# 4     1981-10-19   F  12  no data          198              2
# ...          ...  ..  ..      ...          ...            ...
# 3166  2009-05-08   F  10    195.5          226              0
# 3167  2006-04-03   F  13  no data          227              1
# 3168  2006-04-03   F   1  no data          167            NaN
# 3169  2016-04-22   F  10    202.3      no data              0
# 3170  2010-04-25   F   9    175.5          222              0
#
# [3171 rows x 6 columns]

# %%
cleaned_polarbear['Date'] = pd.to_datetime(cleaned_polarbear['Date'])
cleaned_polarbear['year'] = cleaned_polarbear['Date'].dt.year
cleaned_polarbear
# Out:
# C:\Users\nickn\AppData\Local\Temp\ipykernel_12068\803163165.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_polarbear['Date'] = pd.to_datetime(cleaned_polarbear['Date'])
# C:\Users\nickn\AppData\Local\Temp\ipykernel_12068\803163165.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_polarbear['year'] = cleaned_polarbear['Date'].dt.year
#            Date Sex Age     Mass Total_Length Number_of_cubs  year
# 0    1982-04-09   M  17    267.6          218            NaN  1982
# 1    1986-05-04   M  21  no data          240            NaN  1986
# 2    1987-04-21   M  22  no data          238            NaN  1987
# 3    1987-04-06   F  18  no data          212              0  1987
# 4    1981-10-19   F  12  no data          198              2  1981
# ...         ...  ..  ..      ...          ...            ...   ...
# 3166 2009-05-08   F  10    195.5          226              0  2009
# 3167 2006-04-03   F  13  no data          227              1  2006
# 3168 2006-04-03   F   1  no data          167            NaN  2006
# 3169 2016-04-22   F  10    202.3      no data              0  2016
# 3170 2010-04-25   F   9    175.5          222              0  2010
#
# [3171 rows x 7 columns]

# %%
# Convert 'Age', 'Mass', 'Total_Length', 'Number_of_cubs', and 'year' to float, turning 'no data' into NaN
cleaned_polarbear['Age'] = pd.to_numeric(cleaned_polarbear['Age'], errors='coerce')
cleaned_polarbear['Mass'] = pd.to_numeric(cleaned_polarbear['Mass'], errors='coerce')
cleaned_polarbear['Total_Length'] = pd.to_numeric(cleaned_polarbear['Total_Length'], errors='coerce')
cleaned_polarbear['Number_of_cubs'] = pd.to_numeric(cleaned_polarbear['Number_of_cubs'], errors='coerce')
cleaned_polarbear['year'] = pd.to_numeric(cleaned_polarbear['year'], errors='coerce')

cleaned_polarbear
# Out:
# C:\Users\nickn\AppData\Local\Temp\ipykernel_12068\3658247185.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_polarbear['Age'] = pd.to_numeric(cleaned_polarbear['Age'], errors='coerce')
# C:\Users\nickn\AppData\Local\Temp\ipykernel_12068\3658247185.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_polarbear['Mass'] = pd.to_numeric(cleaned_polarbear['Mass'], errors='coerce')
# C:\Users\nickn\AppData\Local\Temp\ipykernel_12068\3658247185.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_polarbear['Total_Length'] = pd.to_numeric(cleaned_polarbear['Total_Length'], errors='coerce')
# C:\Users\nickn\AppData\Local\Temp\ipykernel_12068\3658247185.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_polarbear['Number_of_cubs'] = pd.to_numeric(cleaned_polarbear['Number_of_cubs'], errors='coerce')
# C:\Users\nickn\AppData\Local\Temp\ipykernel_12068\3658247185.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_polarbear['year'] = pd.to_numeric(cleaned_polarbear['year'], errors='coerce')
#            Date Sex   Age   Mass  Total_Length  Number_of_cubs  year
# 0    1982-04-09   M  17.0  267.6         218.0             NaN  1982
# 1    1986-05-04   M  21.0    NaN         240.0             NaN  1986
# 2    1987-04-21   M  22.0    NaN         238.0             NaN  1987
# 3    1987-04-06   F  18.0    NaN         212.0             0.0  1987
# 4    1981-10-19   F  12.0    NaN         198.0             2.0  1981
# ...         ...  ..   ...    ...           ...             ...   ...
# 3166 2009-05-08   F  10.0  195.5         226.0             0.0  2009
# 3167 2006-04-03   F  13.0    NaN         227.0             1.0  2006
# 3168 2006-04-03   F   1.0    NaN         167.0             NaN  2006
# 3169 2016-04-22   F  10.0  202.3           NaN             0.0  2016
# 3170 2010-04-25   F   9.0  175.5         222.0             0.0  2010
#
# [3171 rows x 7 columns]

# %%
# Handling Missing Values
# Option 1: Drop rows with any missing values in 'Date', 'Sex', 'Number_of_cubs' or'Mass'
df_cleaned = cleaned_polarbear.dropna(subset=['Mass', 'Total_Length', 'year', 'Number_of_cubs'])
df_cleaned
# Out:
#            Date Sex   Age   Mass  Total_Length  Number_of_cubs  year
# 5    1986-04-29   F  17.0  213.2         212.0             2.0  1986
# 7    1985-05-11   F  16.0  204.1         218.0             2.0  1985
# 11   1984-03-28   F  13.0  215.5         226.0             1.0  1984
# 12   1991-04-08   F  22.0  206.4         218.5             0.0  1991
# 13   1992-04-14   F  23.0  158.8         231.0             2.0  1992
# ...         ...  ..   ...    ...           ...             ...   ...
# 3145 2010-04-14   F  10.0  160.6         221.0             2.0  2010
# 3152 2010-04-12   F   8.0  169.6         220.0             2.0  2010
# 3153 2011-04-02   F   9.0  161.0         216.3             2.0  2011
# 3166 2009-05-08   F  10.0  195.5         226.0             0.0  2009
# 3170 2010-04-25   F   9.0  175.5         222.0             0.0  2010
#
# [415 rows x 7 columns]

# %%
#Sample Graph
import seaborn as sns
import matplotlib.pyplot as plt


correlation_coefficient = df_cleaned['Mass'].corr(df_cleaned['Total_Length'])

# Now, create a scatter plot with a regression line
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Mass', y='Total_Length', data=df_cleaned)
sns.regplot(x='Mass', y='Total_Length', data=df_cleaned, scatter=False, color='red')

# Add correlation coefficient to the plot
plt.title(f'Scatter Plot of Mass vs. Total Length with Regression Line\nCorrelation Coefficient: {correlation_coefficient:.2f}')

# Show the plot
plt.show()

# %%
#Sample Graph # 2
import seaborn as sns
import matplotlib.pyplot as plt

# Create a scatter plot with a linear regression line
sns.lmplot(x='Mass', y='Age', data=df_cleaned, aspect=1.5, ci=None, line_kws={'color': 'red'})

# Add title and labels
plt.title('Mass vs Age Linear Regression')
plt.xlabel('Mass')
plt.ylabel('Age')

# Show the plot
plt.show()
# Out:
# C:\Users\nickn\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Sample Graph # 3
import seaborn as sns
import matplotlib.pyplot as plt

# Create a scatter plot with a linear regression line
sns.lmplot(x='year', y='Total_Length', data=df_cleaned, aspect=1.5, ci=None, line_kws={'color': 'red'})

# Add title and labels
plt.title('Total Length vs Time Linear Regression')
plt.xlabel('Length')
plt.ylabel('Time')

# Show the plot
plt.show()
# Out:
# C:\Users\nickn\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Example of Boxplot
import seaborn as sns
import matplotlib.pyplot as plt



# Create a box plot of mass by sex and age
plt.figure(figsize=(20, 10))
sns.boxplot(x='Age', y='Mass',  data=df_cleaned)

# Add title and labels
plt.title('Box Plot of Body Mass by Age')
plt.xlabel('Age')
plt.ylabel('Body Mass')

# Show the plot
plt.show()
