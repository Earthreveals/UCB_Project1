# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from pathlib import Path

# %%
#Read path with Pandas
Polarbear_data = pd.read_csv('polarBear_immunityHormones_beaufort_atwood_2013-2015_v1.csv')
Polarbear_data
# Out:
#      BearID  Year  Day  Ageclass   Age Sex Dependent young  \
# 0     20201  2013   12     Adult  11.0   F             Yes
# 1     20206  2013   26     Adult   NaN   M             NaN
# 2     20300  2013   30     Adult   NaN   M             NaN
# 3     20519  2013   21     Adult   NaN   F              No
# 4     20520  2013   20     Adult   NaN   F             Yes
# ..      ...   ...  ...       ...   ...  ..             ...
# 132   22309  2015   31     Adult   NaN   F             Yes
# 133   22311  2015   45  Subadult   NaN   F              No
# 134   32362  2015   23     Adult   NaN   M             NaN
# 135   32366  2015   44     Adult   NaN   F              No
# 136   32698  2015   30     Adult   NaN   F             Yes
#
#      Number dependent young StatusCurrentYR StatusPriorYR  ...  \
# 0                       2.0             UNK            ON  ...
# 1                       NaN             UNK           UNK  ...
# 2                       NaN             UNK           UNK  ...
# ...

# %%
# Get info on the Dataset
Polarbear_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   BearID                     137 non-null    int64
#  1   Year                       137 non-null    int64
#  2   Day                        137 non-null    int64
#  3   Ageclass                   133 non-null    object
#  4   Age                        42 non-null     float64
#  5   Sex                        137 non-null    object
#  6   Dependent young            74 non-null     object
#  7   Number dependent young     74 non-null     float64
#  8   StatusCurrentYR            137 non-null    object
#  9   StatusPriorYR              137 non-null    object
#  10  YoungPriorYR               6 non-null      float64
#  11  Body length                108 non-null    float64
#  12  Mass                       114 non-null    float64
# ...

# %%
#Get a statistical summary of the dataframe
Polarbear_data.describe()
# Out:
#              BearID         Year         Day        Age  \
# count    137.000000   137.000000  137.000000  42.000000
# mean   21821.357664  2013.905109   20.211679   7.714286
# std     2554.141308     0.821434   10.036280   5.465125
# min    20110.000000  2013.000000    1.000000   2.000000
# 25%    21015.000000  2013.000000   12.000000   3.250000
# 50%    21336.000000  2014.000000   21.000000   5.000000
# 75%    21379.000000  2015.000000   27.000000  11.000000
# max    32821.000000  2015.000000   45.000000  21.000000
#
#        Number dependent young  YoungPriorYR  Body length        Mass  \
# count               74.000000      6.000000   108.000000  114.000000
# mean                 0.527027      0.833333   201.168519  231.674298
# std                  0.762530      0.983192    20.286926   97.568670
# min                  0.000000      0.000000   105.800000   92.080000
# 25%                  0.000000      0.000000   190.000000  174.745000
# ...

# %% [markdown]
# Filter Data by Year, Sex, BearID, Body lenth, Mass, BMI

# %%
# Filter the DataFrame for the years 2013, 2014, and 2015
df_filtered_years = Polarbear_data[Polarbear_data['Year'].isin([2013, 2014, 2015])]
df_filtered_years
# Out:
#      BearID  Year  Day  Ageclass   Age Sex Dependent young  \
# 0     20201  2013   12     Adult  11.0   F             Yes
# 1     20206  2013   26     Adult   NaN   M             NaN
# 2     20300  2013   30     Adult   NaN   M             NaN
# 3     20519  2013   21     Adult   NaN   F              No
# 4     20520  2013   20     Adult   NaN   F             Yes
# ..      ...   ...  ...       ...   ...  ..             ...
# 132   22309  2015   31     Adult   NaN   F             Yes
# 133   22311  2015   45  Subadult   NaN   F              No
# 134   32362  2015   23     Adult   NaN   M             NaN
# 135   32366  2015   44     Adult   NaN   F              No
# 136   32698  2015   30     Adult   NaN   F             Yes
#
#      Number dependent young StatusCurrentYR StatusPriorYR  ...  \
# 0                       2.0             UNK            ON  ...
# 1                       NaN             UNK           UNK  ...
# 2                       NaN             UNK           UNK  ...
# ...

# %%
# Select columns that will explore relationship between sex, year and body mass
df_filtered = df_filtered_years[['Year', 'Sex', 'Body length', 'Mass', 'BMI']]
df_filtered
# Out:
#      Year Sex  Body length    Mass     BMI
# 0    2013   F          NaN  187.79     NaN
# 1    2013   M        236.0  476.27  68.397
# 2    2013   M        231.0  398.25  56.762
# 3    2013   F          NaN  204.57  39.045
# 4    2013   F        196.4  194.14  42.629
# ..    ...  ..          ...     ...     ...
# 132  2015   F        181.0  132.00  35.838
# 133  2015   F        186.0  142.88  35.398
# 134  2015   M        224.0  408.69  65.975
# 135  2015   F        195.5  168.28  36.779
# 136  2015   F        184.5  175.54  43.489
#
# [137 rows x 5 columns]

# %% [markdown]
# CLEANING DATA

# %%
# Handling Missing Values
# Option 1: Drop rows with any missing values in 'Body length', 'Mass', or 'BMI'
df_cleaned = df_filtered.dropna(subset=['Body length', 'Mass', 'BMI'])
df_cleaned
# Out:
#      Year Sex  Body length    Mass     BMI
# 1    2013   M        236.0  476.27  68.397
# 2    2013   M        231.0  398.25  56.762
# 4    2013   F        196.4  194.14  42.629
# 5    2013   F        190.8  179.62  42.366
# 6    2013   F        201.5  231.33  49.307
# ..    ...  ..          ...     ...     ...
# 132  2015   F        181.0  132.00  35.838
# 133  2015   F        186.0  142.88  35.398
# 134  2015   M        224.0  408.69  65.975
# 135  2015   F        195.5  168.28  36.779
# 136  2015   F        184.5  175.54  43.489
#
# [106 rows x 5 columns]

# %%
# Filter data by Year, Sex, BMI and Hormones via dataframe
filter_Hormones =['Year', 'Sex', 'BMI', 'Storage energy', 'Hair cortisol', 'UCratio', 'Hair estradiol (ng/ml)', 'Serum estradiol', 'Hair progesterone (ng/ml)', 'Serum progesterone', 'Hair testosterone (ng/ml)', 'Serum testosterone']
df_filter_Hormones= Polarbear_data[filter_Hormones]
df_filter_Hormones
# Out:
#      Year Sex     BMI  Storage energy  Hair cortisol  UCratio  \
# 0    2013   F     NaN             NaN          2.301    27.11
# 1    2013   M  68.397        3935.253          3.322      NaN
# 2    2013   M  56.762        2351.392          4.901      NaN
# 3    2013   F  39.045         662.399          2.441      NaN
# 4    2013   F  42.629        1278.752          3.327      NaN
# ..    ...  ..     ...             ...            ...      ...
# 132  2015   F  35.838         689.332          5.205     7.95
# 133  2015   F  35.398         525.328          6.071      NaN
# 134  2015   M  65.975        3478.928          3.585      NaN
# 135  2015   F  36.779         575.536          3.014    20.20
# 136  2015   F  43.489        1421.407          6.039    56.71
#
#      Hair estradiol (ng/ml)  Serum estradiol  Hair progesterone (ng/ml)  \
# 0                    24.545            0.485                      0.026
# 1                       NaN              NaN                        NaN
# ...

# %%
#Handling missing values for various Hormones
df_cleaned_Hormone = df_filter_Hormones.dropna(subset=['Year', 'Sex', 'BMI', 'Storage energy', 'Hair cortisol'])
df_cleaned_Hormone.head()
# Out:
#    Year Sex     BMI  Storage energy  Hair cortisol  UCratio  \
# 1  2013   M  68.397        3935.253          3.322      NaN
# 2  2013   M  56.762        2351.392          4.901      NaN
# 3  2013   F  39.045         662.399          2.441      NaN
# 4  2013   F  42.629        1278.752          3.327      NaN
# 5  2013   F  42.366        1285.612          3.177      NaN
#
#    Hair estradiol (ng/ml)  Serum estradiol  Hair progesterone (ng/ml)  \
# 1                     NaN              NaN                        NaN
# 2                     NaN              NaN                        NaN
# 3                  23.261            0.193                      0.018
# 4                  22.971            0.210                      0.091
# 5                  21.509            0.127                      0.020
#
#    Serum progesterone  Hair testosterone (ng/ml)  Serum testosterone
# 1                 NaN                      0.012              25.736
# ...

# %%
#Handling missing values for various Hormones- "UCratio"
df_cleaned_Hormone_UCratio = df_filter_Hormones.dropna(subset=['Year', 'Sex', 'BMI', 'Storage energy', 'UCratio',])
df_cleaned_Hormone_UCratio.head()
# Out:
#     Year Sex     BMI  Storage energy  Hair cortisol  UCratio  \
# 6   2013   F  49.307        2078.426          5.328    22.65
# 12  2013   M  64.352        3298.855          1.551     5.11
# 16  2013   F  43.562        1365.626          2.979     9.75
# 23  2013   M  48.785        1425.850          2.116     2.38
# 24  2013   F  41.113        1109.077          3.854    59.86
#
#     Hair estradiol (ng/ml)  Serum estradiol  Hair progesterone (ng/ml)  \
# 6                   22.737            0.412                      0.053
# 12                     NaN              NaN                        NaN
# 16                  22.916            0.040                      0.038
# 23                     NaN              NaN                        NaN
# 24                  23.468            0.044                      0.033
#
#     Serum progesterone  Hair testosterone (ng/ml)  Serum testosterone
# 6                0.334                        NaN                 NaN
# ...

# %%
#Handling missing values for various Hormones
df_cleaned_Hormone_Hairestradiol = df_filter_Hormones.dropna(subset=['Year', 'Sex', 'BMI', 'Storage energy', 'Hair estradiol (ng/ml)'])
df_cleaned_Hormone_Hairestradiol
# Out:
#      Year Sex     BMI  Storage energy  Hair cortisol  UCratio  \
# 3    2013   F  39.045         662.399          2.441      NaN
# 4    2013   F  42.629        1278.752          3.327      NaN
# 5    2013   F  42.366        1285.612          3.177      NaN
# 6    2013   F  49.307        2078.426          5.328    22.65
# 13   2013   F  46.332        1709.785          1.768      NaN
# ..    ...  ..     ...             ...            ...      ...
# 131  2015   F  38.548         893.725          6.977      NaN
# 132  2015   F  35.838         689.332          5.205     7.95
# 133  2015   F  35.398         525.328          6.071      NaN
# 135  2015   F  36.779         575.536          3.014    20.20
# 136  2015   F  43.489        1421.407          6.039    56.71
#
#      Hair estradiol (ng/ml)  Serum estradiol  Hair progesterone (ng/ml)  \
# 3                    23.261            0.193                      0.018
# 4                    22.971            0.210                      0.091
# ...

# %%
#Handling missing values for various Hormones- Serum estradiol
df_cleaned_Hormone_Serum_estradiol = df_filter_Hormones.dropna(subset=['Year', 'Sex', 'BMI', 'Storage energy', 'Serum estradiol'])
df_cleaned_Hormone_Serum_estradiol
# Out:
#      Year Sex     BMI  Storage energy  Hair cortisol  UCratio  \
# 3    2013   F  39.045         662.399          2.441      NaN
# 4    2013   F  42.629        1278.752          3.327      NaN
# 5    2013   F  42.366        1285.612          3.177      NaN
# 6    2013   F  49.307        2078.426          5.328    22.65
# 13   2013   F  46.332        1709.785          1.768      NaN
# ..    ...  ..     ...             ...            ...      ...
# 131  2015   F  38.548         893.725          6.977      NaN
# 132  2015   F  35.838         689.332          5.205     7.95
# 133  2015   F  35.398         525.328          6.071      NaN
# 135  2015   F  36.779         575.536          3.014    20.20
# 136  2015   F  43.489        1421.407          6.039    56.71
#
#      Hair estradiol (ng/ml)  Serum estradiol  Hair progesterone (ng/ml)  \
# 3                    23.261            0.193                      0.018
# 4                    22.971            0.210                      0.091
# ...

# %%
#Handling missing values for various Hormones- Hair progesterone
df_cleaned_Hormone_Hair_progesterone_ngml = df_filter_Hormones.dropna(subset=['Year', 'Sex', 'BMI', 'Storage energy', 'Hair progesterone (ng/ml)'])
df_cleaned_Hormone_Hair_progesterone_ngml.head()
# Out:
#     Year Sex     BMI  Storage energy  Hair cortisol  UCratio  \
# 3   2013   F  39.045         662.399          2.441      NaN
# 4   2013   F  42.629        1278.752          3.327      NaN
# 5   2013   F  42.366        1285.612          3.177      NaN
# 6   2013   F  49.307        2078.426          5.328    22.65
# 13  2013   F  46.332        1709.785          1.768      NaN
#
#     Hair estradiol (ng/ml)  Serum estradiol  Hair progesterone (ng/ml)  \
# 3                   23.261            0.193                      0.018
# 4                   22.971            0.210                      0.091
# 5                   21.509            0.127                      0.020
# 6                   22.737            0.412                      0.053
# 13                  23.054            0.435                      0.018
#
#     Serum progesterone  Hair testosterone (ng/ml)  Serum testosterone
# 3                0.996                        NaN                 NaN
# ...

# %%
#Handling missing values for various Hormones- Serum progesterone
df_cleaned_Hormone_Serum_progesterone = df_filter_Hormones.dropna(subset=['Year', 'Sex', 'BMI', 'Storage energy', 'Serum progesterone'])
df_cleaned_Hormone_Serum_progesterone.head()
# Out:
#     Year Sex     BMI  Storage energy  Hair cortisol  UCratio  \
# 3   2013   F  39.045         662.399          2.441      NaN
# 4   2013   F  42.629        1278.752          3.327      NaN
# 5   2013   F  42.366        1285.612          3.177      NaN
# 6   2013   F  49.307        2078.426          5.328    22.65
# 13  2013   F  46.332        1709.785          1.768      NaN
#
#     Hair estradiol (ng/ml)  Serum estradiol  Hair progesterone (ng/ml)  \
# 3                   23.261            0.193                      0.018
# 4                   22.971            0.210                      0.091
# 5                   21.509            0.127                      0.020
# 6                   22.737            0.412                      0.053
# 13                  23.054            0.435                      0.018
#
#     Serum progesterone  Hair testosterone (ng/ml)  Serum testosterone
# 3                0.996                        NaN                 NaN
# ...

# %%
#Handling missing values for various Hormones- Hair testosteron (ng/ml)
df_cleaned_Hormone_Hair_testosterone_ngml = df_filter_Hormones.dropna(subset=['Year', 'Sex', 'BMI', 'Storage energy', 'Hair testosterone (ng/ml)'])
df_cleaned_Hormone_Hair_testosterone_ngml.head()
# Out:
#     Year Sex     BMI  Storage energy  Hair cortisol  UCratio  \
# 1   2013   M  68.397        3935.253          3.322      NaN
# 2   2013   M  56.762        2351.392          4.901      NaN
# 7   2013   M  75.308        4569.119          3.035      NaN
# 8   2013   M  67.991        3734.377          3.220      NaN
# 12  2013   M  64.352        3298.855          1.551     5.11
#
#     Hair estradiol (ng/ml)  Serum estradiol  Hair progesterone (ng/ml)  \
# 1                      NaN              NaN                        NaN
# 2                      NaN              NaN                        NaN
# 7                      NaN              NaN                        NaN
# 8                      NaN              NaN                        NaN
# 12                     NaN              NaN                        NaN
#
#     Serum progesterone  Hair testosterone (ng/ml)  Serum testosterone
# 1                  NaN                      0.012              25.736
# ...

# %%
#Handling missing values for various Hormones- Serum testosterone
df_cleaned_Hormone_Serum_testosterone = df_filter_Hormones.dropna(subset=['Year', 'Sex', 'BMI', 'Storage energy', 'Serum testosterone'])
df_cleaned_Hormone_Serum_testosterone.head()
# Out:
#     Year Sex     BMI  Storage energy  Hair cortisol  UCratio  \
# 1   2013   M  68.397        3935.253          3.322      NaN
# 2   2013   M  56.762        2351.392          4.901      NaN
# 7   2013   M  75.308        4569.119          3.035      NaN
# 8   2013   M  67.991        3734.377          3.220      NaN
# 12  2013   M  64.352        3298.855          1.551     5.11
#
#     Hair estradiol (ng/ml)  Serum estradiol  Hair progesterone (ng/ml)  \
# 1                      NaN              NaN                        NaN
# 2                      NaN              NaN                        NaN
# 7                      NaN              NaN                        NaN
# 8                      NaN              NaN                        NaN
# 12                     NaN              NaN                        NaN
#
#     Serum progesterone  Hair testosterone (ng/ml)  Serum testosterone
# 1                  NaN                      0.012              25.736
# ...
